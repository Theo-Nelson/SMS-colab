# %% [markdown]
# #HW1 - Notebook Setup: Single Molecule Sequencing Methods Training Applications

# %% [markdown]
# Theodore M. Nelson

# %% [markdown]
# The teaching objective is to successfully connect your Google Drive with the current and upcoming homework and in-class assignments.
#
# Google Drive is organized in a file structure which can be traversed similar to a file format system. As such, data will be provided primarily via Google Drive. Each free Google Drive system receives 15 GB of storage; each Google Colab notebook session (temporary) receives 100 GB of storage, along with an individual virtual machine with 12 GB of RAM.

# %% [markdown]
# ##Process 1: Make the Google Drive Folder Accessible from Your Home Directory [Allows for More Permanent Storage of Results]

# %% [markdown]
# Link the relevant assignment drive directory to your home directory via a shortcut. After right clicking on the directory name, follow the two steps shown below:
#
# **Step 1**: https://u.cubeupload.com/MakeTheBrainHappy/Screenshot20240406at.png (also shown below)
#
# **Step 2**: https://u.cubeupload.com/MakeTheBrainHappy/5faScreenshot20240406at.png

# %% [markdown]
# ![Screenshot 2024-04-06 at 3.33.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# ##Process 2: Mount the Google Drive & Access Data in Colab

# %% [markdown]
# Run the cell below with the run key to the left. Please accept all requested permissions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We can now access files / data within the HW1 folder via bash commands, prefixed by a ! point.

# %%
! head -n 10 /content/drive/MyDrive/HW1/HCV_IVT_reads_test_one_read.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821
# @asic_version	Unknown
# @barcoding_enabled	0
# @configuration_version	5.8.6
# @data_source	real_device
# @device_id	2C

# %% [markdown]
# There are many ways to access the same piece of data~! 'cd' in this context stands for change directory.

# %%
! cd /content/drive/MyDrive/HW1 ; head -n 10 HCV_IVT_reads_test_one_read.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821
# @asic_version	Unknown
# @barcoding_enabled	0
# @configuration_version	5.8.6
# @data_source	real_device
# @device_id	2C

# %% [markdown]
# We can change the -n parameter on the head command to see more or less of the file!

# %%
! cd /content/drive/MyDrive/HW1 ; head -n 5 HCV_IVT_reads_test_one_read.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821

# %% [markdown]
# If we change it to -60, we'll see the entire format for a .slow5 file, including the signal level data (see the scroll bar at the bottom).

# %%
! cd /content/drive/MyDrive/HW1 ; head -n 60 HCV_IVT_reads_test_one_read.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821
# @asic_version	Unknown
# @barcoding_enabled	0
# @configuration_version	5.8.6
# @data_source	real_device
# @device_id	2C
# @device_type	promethion
# @distribution_status	stable
# @distribution_version	23.11.7
# @exp_script_name	sequencing/sequencing_PRO004RA_RNA:FLO-PRO004RA:SQK-RNA004:130
# @exp_script_purpose	sequencing_run
# @exp_start_time	2024-02-23T16:51:12.691607-05:00
# @experiment_type	rna
# @file_type	multi-read
# @file_version	3.2
# @flow_cell_id	PAU73487
# @flow_cell_product_code	FLO-PRO004RA
# @guppy_version	7.2.13+fba8e8925
# @heatsink_temp	33.125660
# @host_product_code	PRO-SEQ024
# @host_product_serial_number	PEARL
# @hostname	pearl
# @hublett_board_id	0001a08dab68dae7
# @hublett_firmware_version	2.1.10
# @installation_type	nc
# @is_simulated	0
# @local_basecalling	0
# @operating_system	ubuntu 20.04
# @package	bream4
# @package_version	7.8.2
# ...

# %% [markdown]
# ##Process #3: Download + Use Data from Github

# %% [markdown]
# We can download files with the wget command.

# %%
! wget https://github.com/Theo-Nelson/SMS-data/raw/main/HCV/HCV_IVT_004_ONE_RANDOM_READ.slow5
# Out:
# --2024-04-17 21:53:42--  https://github.com/Theo-Nelson/SMS-data/raw/main/HCV/HCV_IVT_004_ONE_RANDOM_READ.slow5
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Theo-Nelson/SMS-data/main/HCV/HCV_IVT_004_ONE_RANDOM_READ.slow5 [following]
# --2024-04-17 21:53:43--  https://raw.githubusercontent.com/Theo-Nelson/SMS-data/main/HCV/HCV_IVT_004_ONE_RANDOM_READ.slow5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63212 (62K) [text/plain]
# Saving to: ‘HCV_IVT_004_ONE_RANDOM_READ.slow5’
#
# HCV_IVT_004_ONE_RAN 100%[===================>]  61.73K  --.-KB/s    in 0.009s
#
# ...

# %% [markdown]
# We can utilize the same commands as above to inspect this file.

# %%
! head -n 10 HCV_IVT_004_ONE_RANDOM_READ.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821
# @asic_version	Unknown
# @barcoding_enabled	0
# @configuration_version	5.8.6
# @data_source	real_device
# @device_id	2C

# %%
! head -n 5 HCV_IVT_004_ONE_RANDOM_READ.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821

# %%
! head -n 60 HCV_IVT_004_ONE_RANDOM_READ.slow5
# Out:
# #slow5_version	0.2.0
# #num_read_groups	1
# @asic_id	FFFFFC0FE7396351
# @asic_id_eeprom	FFFFFC0FE7396351
# @asic_temp	50.574821
# @asic_version	Unknown
# @barcoding_enabled	0
# @configuration_version	5.8.6
# @data_source	real_device
# @device_id	2C
# @device_type	promethion
# @distribution_status	stable
# @distribution_version	23.11.7
# @exp_script_name	sequencing/sequencing_PRO004RA_RNA:FLO-PRO004RA:SQK-RNA004:130
# @exp_script_purpose	sequencing_run
# @exp_start_time	2024-02-23T16:51:12.691607-05:00
# @experiment_type	rna
# @file_type	multi-read
# @file_version	3.2
# @flow_cell_id	PAU73487
# @flow_cell_product_code	FLO-PRO004RA
# @guppy_version	7.2.13+fba8e8925
# @heatsink_temp	33.125660
# @host_product_code	PRO-SEQ024
# @host_product_serial_number	PEARL
# @hostname	pearl
# @hublett_board_id	0001a08dab68dae7
# @hublett_firmware_version	2.1.10
# @installation_type	nc
# @is_simulated	0
# @local_basecalling	0
# @operating_system	ubuntu 20.04
# @package	bream4
# @package_version	7.8.2
# ...
